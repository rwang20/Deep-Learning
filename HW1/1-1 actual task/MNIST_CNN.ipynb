# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
import os
import math
import tensorflow as tf
from tensorflow import keras

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
from tensorflow.keras.datasets import mnist

# %%
(x_train_all, y_train_all), (x_test, y_test) = mnist.load_data()
x_valid, x_train = x_train_all[:5000], x_train_all[5000:]
y_valid, y_train = y_train_all[:5000], y_train_all[5000:]

print(x_valid.shape, y_valid.shape)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (5000, 28, 28) (5000,)
# (55000, 28, 28) (55000,)
# (10000, 28, 28) (10000,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(
    x_train.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28, 1)
x_valid_scaled = scaler.transform(
    x_valid.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28, 1)
x_test_scaled = scaler.transform(
    x_test.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28, 1)

# %%
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel([y_train[i]])
plt.show()

# %%
from tensorflow.keras import datasets, layers, models
from tensorflow.keras import regularizers

# %%
# training model1
model1 = keras.models.Sequential()

model1.add(keras.layers.Conv2D(filters=16, kernel_size=5,padding='same',
                             activation='relu',input_shape=(28, 28, 1)))
model1.add(keras.layers.MaxPool2D(pool_size=2))

model1.add(keras.layers.Flatten())
model1.add(keras.layers.Dense(128, activation='relu'))
model1.add(keras.layers.Dense(10, activation="softmax"))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        416
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               401536
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 403,242
# Trainable params: 403,242
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss="sparse_categorical_crossentropy",
             optimizer = "adam",
             metrics = ["accuracy"])

# %%
history1 = model1.fit(x_train_scaled, y_train, epochs=60,
                    validation_data=(x_valid_scaled, y_valid))
# Out:
# Epoch 1/60
# 1719/1719 [==============================] - 16s 9ms/step - loss: 0.2906 - accuracy: 0.9099 - val_loss: 0.0646 - val_accuracy: 0.9802
# Epoch 2/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0523 - accuracy: 0.9830 - val_loss: 0.0521 - val_accuracy: 0.9842
# Epoch 3/60
# 1719/1719 [==============================] - 15s 8ms/step - loss: 0.0320 - accuracy: 0.9901 - val_loss: 0.0457 - val_accuracy: 0.9878
# Epoch 4/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0220 - accuracy: 0.9926 - val_loss: 0.0410 - val_accuracy: 0.9894
# Epoch 5/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0487 - val_accuracy: 0.9858
# Epoch 6/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.0475 - val_accuracy: 0.9882
# Epoch 7/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0616 - val_accuracy: 0.9842
# Epoch 8/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0536 - val_accuracy: 0.9894
# Epoch 9/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0743 - val_accuracy: 0.9848
# Epoch 10/60
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0605 - val_accuracy: 0.9886
# Epoch 11/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0555 - val_accuracy: 0.9898
# Epoch 12/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0538 - val_accuracy: 0.9892
# Epoch 13/60
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0749 - val_accuracy: 0.9862
# Epoch 14/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0761 - val_accuracy: 0.9858
# Epoch 15/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0617 - val_accuracy: 0.9892
# Epoch 16/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0670 - val_accuracy: 0.9880
# Epoch 17/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.0758 - val_accuracy: 0.9870
# Epoch 18/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.1007 - val_accuracy: 0.9874
# Epoch 19/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0817 - val_accuracy: 0.9894
# Epoch 20/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0833 - val_accuracy: 0.9884
# Epoch 21/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0973 - val_accuracy: 0.9870
# Epoch 22/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.1008 - val_accuracy: 0.9874
# Epoch 23/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.0931 - val_accuracy: 0.9868
# Epoch 24/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1267 - val_accuracy: 0.9816
# Epoch 25/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0081 - accuracy: 0.9983 - val_loss: 0.0992 - val_accuracy: 0.9868
# Epoch 26/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1202 - val_accuracy: 0.9864
# Epoch 27/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.1173 - val_accuracy: 0.9874
# Epoch 28/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.1194 - val_accuracy: 0.9884
# Epoch 29/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.1232 - val_accuracy: 0.9868
# Epoch 30/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 0.1101 - val_accuracy: 0.9878
# Epoch 31/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1028 - val_accuracy: 0.9886
# Epoch 32/60
# 1719/1719 [==============================] - 15s 9ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0870 - val_accuracy: 0.9900
# Epoch 33/60
# 1719/1719 [==============================] - 15s 9ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.1137 - val_accuracy: 0.9874
# Epoch 34/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 2.9130e-04 - accuracy: 0.9999 - val_loss: 0.1064 - val_accuracy: 0.9904
# Epoch 35/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.1165 - val_accuracy: 0.9882
# Epoch 36/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.1435 - val_accuracy: 0.9866
# Epoch 37/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.1220 - val_accuracy: 0.9900
# Epoch 38/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1452 - val_accuracy: 0.9854
# Epoch 39/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.1667 - val_accuracy: 0.9872
# Epoch 40/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.1391 - val_accuracy: 0.9874
# Epoch 41/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.1205 - val_accuracy: 0.9898
# Epoch 42/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.1409 - val_accuracy: 0.9882
# Epoch 43/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1532 - val_accuracy: 0.9884
# Epoch 44/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.1390 - val_accuracy: 0.9890
# Epoch 45/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1415 - val_accuracy: 0.9874
# Epoch 46/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.1380 - val_accuracy: 0.9886
# Epoch 47/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 2.9012e-04 - accuracy: 0.9999 - val_loss: 0.1589 - val_accuracy: 0.9892
# Epoch 48/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.2111 - val_accuracy: 0.9856
# Epoch 49/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1517 - val_accuracy: 0.9894
# Epoch 50/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.1723 - val_accuracy: 0.9882
# Epoch 51/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.1713 - val_accuracy: 0.9888
# Epoch 52/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1580 - val_accuracy: 0.9876
# Epoch 53/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.1509 - val_accuracy: 0.9892
# Epoch 54/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1443 - val_accuracy: 0.9886
# Epoch 55/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.1263 - val_accuracy: 0.9906
# Epoch 56/60
# 1719/1719 [==============================] - 14s 8ms/step - loss: 4.6739e-04 - accuracy: 0.9999 - val_loss: 0.1517 - val_accuracy: 0.9894
# Epoch 57/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.1465 - val_accuracy: 0.9910
# Epoch 58/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 5.3040e-04 - accuracy: 0.9997 - val_loss: 0.1595 - val_accuracy: 0.9888
# Epoch 59/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.1567 - val_accuracy: 0.9902
# Epoch 60/60
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1611 - val_accuracy: 0.9884

# %%
plt.plot(history1.history['loss'])
plt.title('Model1 loss')
plt.ylabel('Train Loss')
plt.xlabel('Epoch')
plt.show()

plt.plot(history1.history['accuracy'], label = 'train acc')
plt.plot(history1.history['val_accuracy'], label = 'valid acc')
plt.title('Model1 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# training model2
model2 = keras.models.Sequential()

model2.add(keras.layers.Conv2D(filters=16, kernel_size=5,padding='same',
                             activation='relu',input_shape=(28, 28, 1)))
model2.add(keras.layers.MaxPool2D(pool_size=2))

model2.add(keras.layers.Conv2D(64,5,padding='same',activation='relu'))
model2.add(keras.layers.MaxPool2D(pool_size=2))

model2.add(keras.layers.Flatten())
model2.add(keras.layers.Dense(128, activation='relu'))
model2.add(keras.layers.Dense(10, activation="softmax"))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        25664
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               401536
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 428,906
# Trainable params: 428,906
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss="sparse_categorical_crossentropy",
             optimizer = "adam",
             metrics = ["accuracy"])

# %%
history2 = model2.fit(x_train_scaled, y_train, epochs=60,
                    validation_data=(x_valid_scaled, y_valid))
# Out:
# Epoch 1/60
# 1719/1719 [==============================] - 35s 20ms/step - loss: 0.2508 - accuracy: 0.9221 - val_loss: 0.0497 - val_accuracy: 0.9852
# Epoch 2/60
# 1719/1719 [==============================] - 35s 20ms/step - loss: 0.0421 - accuracy: 0.9863 - val_loss: 0.0385 - val_accuracy: 0.9878
# Epoch 3/60
# 1719/1719 [==============================] - 36s 21ms/step - loss: 0.0254 - accuracy: 0.9919 - val_loss: 0.0335 - val_accuracy: 0.9892
# Epoch 4/60
# 1719/1719 [==============================] - 35s 20ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.0392 - val_accuracy: 0.9888
# Epoch 5/60
# 1719/1719 [==============================] - 35s 21ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0431 - val_accuracy: 0.9878
# Epoch 6/60
# 1719/1719 [==============================] - 31s 18ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.0308 - val_accuracy: 0.9910
# Epoch 7/60
# 1719/1719 [==============================] - 31s 18ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.0385 - val_accuracy: 0.9912
# Epoch 8/60
# 1719/1719 [==============================] - 30s 18ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0448 - val_accuracy: 0.9880
# Epoch 9/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.0511 - val_accuracy: 0.9880
# Epoch 10/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0405 - val_accuracy: 0.9930
# Epoch 11/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0635 - val_accuracy: 0.9894
# Epoch 12/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0719 - val_accuracy: 0.9920
# Epoch 13/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0510 - val_accuracy: 0.9916
# Epoch 14/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0707 - val_accuracy: 0.9878
# Epoch 15/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0545 - val_accuracy: 0.9906
# Epoch 16/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0745 - val_accuracy: 0.9902
# Epoch 17/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.0684 - val_accuracy: 0.9922
# Epoch 18/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0719 - val_accuracy: 0.9912
# Epoch 19/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0496 - val_accuracy: 0.9926
# Epoch 20/60
# 1719/1719 [==============================] - 28s 17ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0874 - val_accuracy: 0.9878
# Epoch 21/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.0647 - val_accuracy: 0.9922
# Epoch 22/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.1082 - val_accuracy: 0.9880
# Epoch 23/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.0876 - val_accuracy: 0.9916
# Epoch 24/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.1332 - val_accuracy: 0.9868
# Epoch 25/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0082 - accuracy: 0.9981 - val_loss: 0.0981 - val_accuracy: 0.9918
# Epoch 26/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.1137 - val_accuracy: 0.9916
# Epoch 27/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.1248 - val_accuracy: 0.9892
# Epoch 28/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0068 - accuracy: 0.9987 - val_loss: 0.0834 - val_accuracy: 0.9914
# Epoch 29/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0822 - val_accuracy: 0.9910
# Epoch 30/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0054 - accuracy: 0.9989 - val_loss: 0.0781 - val_accuracy: 0.9926
# Epoch 31/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.1003 - val_accuracy: 0.9912
# Epoch 32/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0070 - accuracy: 0.9988 - val_loss: 0.1088 - val_accuracy: 0.9914
# Epoch 33/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 0.1153 - val_accuracy: 0.9910
# Epoch 34/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0921 - val_accuracy: 0.9916
# Epoch 35/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.0979 - val_accuracy: 0.9936
# Epoch 36/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.1894 - val_accuracy: 0.9890
# Epoch 37/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0099 - accuracy: 0.9985 - val_loss: 0.1091 - val_accuracy: 0.9910
# Epoch 38/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0107 - accuracy: 0.9988 - val_loss: 0.1525 - val_accuracy: 0.9888
# Epoch 39/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.1123 - val_accuracy: 0.9928
# Epoch 40/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.1355 - val_accuracy: 0.9888
# Epoch 41/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.1131 - val_accuracy: 0.9922
# Epoch 42/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.1107 - val_accuracy: 0.9918
# Epoch 43/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.1630 - val_accuracy: 0.9884
# Epoch 44/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0073 - accuracy: 0.9987 - val_loss: 0.1522 - val_accuracy: 0.9896
# Epoch 45/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.1991 - val_accuracy: 0.9878
# Epoch 46/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0081 - accuracy: 0.9990 - val_loss: 0.1530 - val_accuracy: 0.9926
# Epoch 47/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0049 - accuracy: 0.9993 - val_loss: 0.1417 - val_accuracy: 0.9920
# Epoch 48/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0046 - accuracy: 0.9995 - val_loss: 0.1467 - val_accuracy: 0.9904
# Epoch 49/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.1172 - val_accuracy: 0.9918
# Epoch 50/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0070 - accuracy: 0.9989 - val_loss: 0.1318 - val_accuracy: 0.9914
# Epoch 51/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0090 - accuracy: 0.9988 - val_loss: 0.1469 - val_accuracy: 0.9920
# Epoch 52/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.1542 - val_accuracy: 0.9916
# Epoch 53/60
# 1719/1719 [==============================] - 29s 17ms/step - loss: 0.0040 - accuracy: 0.9995 - val_loss: 0.2049 - val_accuracy: 0.9886
# Epoch 54/60
# 1719/1719 [==============================] - 28s 17ms/step - loss: 0.0076 - accuracy: 0.9989 - val_loss: 0.1815 - val_accuracy: 0.9914
# Epoch 55/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0053 - accuracy: 0.9993 - val_loss: 0.1775 - val_accuracy: 0.9916
# Epoch 56/60
# 1719/1719 [==============================] - 26s 15ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.1548 - val_accuracy: 0.9910
# Epoch 57/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0056 - accuracy: 0.9993 - val_loss: 0.1636 - val_accuracy: 0.9910
# Epoch 58/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 9.9722e-04 - accuracy: 0.9996 - val_loss: 0.1821 - val_accuracy: 0.9912
# Epoch 59/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0051 - accuracy: 0.9991 - val_loss: 0.2130 - val_accuracy: 0.9914
# Epoch 60/60
# 1719/1719 [==============================] - 27s 16ms/step - loss: 0.0049 - accuracy: 0.9995 - val_loss: 0.2313 - val_accuracy: 0.9910

# %%
plt.plot(history2.history['loss'])
plt.title('Model2 loss')
plt.ylabel('Train Loss')
plt.xlabel('Epoch')
plt.show()

plt.plot(history2.history['accuracy'], label = 'train acc')
plt.plot(history2.history['val_accuracy'], label = 'valid acc')
plt.title('Model2 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# training model3
model3 = keras.models.Sequential()

model3.add(keras.layers.Conv2D(filters=16, kernel_size=5,padding='same',
                             activation='relu',input_shape=(28, 28, 1)))
model3.add(keras.layers.MaxPool2D(pool_size=2))

model3.add(keras.layers.Flatten())
model3.add(keras.layers.Dense(130, activation='relu'))
model3.add(keras.layers.Dense(50, activation='relu'))
model3.add(keras.layers.Dense(10, activation="softmax"))

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 28, 28, 16)        416
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 130)               407810
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                6550
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                510
# =================================================================
# Total params: 415,286
# Trainable params: 415,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(loss="sparse_categorical_crossentropy",
             optimizer = "adam",
             metrics = ["accuracy"])

# %%
history3 = model3.fit(x_train_scaled, y_train, epochs=60,
                    validation_data=(x_valid_scaled, y_valid))
# Out:
# Epoch 1/60
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2993 - accuracy: 0.9061 - val_loss: 0.0625 - val_accuracy: 0.9796
# Epoch 2/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0570 - accuracy: 0.9818 - val_loss: 0.0551 - val_accuracy: 0.9838
# Epoch 3/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0345 - accuracy: 0.9887 - val_loss: 0.0506 - val_accuracy: 0.9838
# Epoch 4/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 0.0467 - val_accuracy: 0.9878
# Epoch 5/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0182 - accuracy: 0.9947 - val_loss: 0.0463 - val_accuracy: 0.9870
# Epoch 6/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.0558 - val_accuracy: 0.9868
# Epoch 7/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.0505 - val_accuracy: 0.9868
# Epoch 8/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0543 - val_accuracy: 0.9902
# Epoch 9/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0587 - val_accuracy: 0.9882
# Epoch 10/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0542 - val_accuracy: 0.9894
# Epoch 11/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0563 - val_accuracy: 0.9878
# Epoch 12/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.0731 - val_accuracy: 0.9866
# Epoch 13/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0781 - val_accuracy: 0.9864
# Epoch 14/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0584 - val_accuracy: 0.9888
# Epoch 15/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0656 - val_accuracy: 0.9892
# Epoch 16/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.0677 - val_accuracy: 0.9858
# Epoch 17/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.0841 - val_accuracy: 0.9884
# Epoch 18/60
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0800 - val_accuracy: 0.9860
# Epoch 19/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0814 - val_accuracy: 0.9890
# Epoch 20/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.1024 - val_accuracy: 0.9848
# Epoch 21/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.1074 - val_accuracy: 0.9876
# Epoch 22/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.0927 - val_accuracy: 0.9880
# Epoch 23/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.1027 - val_accuracy: 0.9864
# Epoch 24/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.0985 - val_accuracy: 0.9878
# Epoch 25/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.1125 - val_accuracy: 0.9852
# Epoch 26/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.0810 - val_accuracy: 0.9892
# Epoch 27/60
# 1719/1719 [==============================] - 9s 6ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.1047 - val_accuracy: 0.9854
# Epoch 28/60
# 1719/1719 [==============================] - 9s 6ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1195 - val_accuracy: 0.9872
# Epoch 29/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.1153 - val_accuracy: 0.9868
# Epoch 30/60
# 1719/1719 [==============================] - 9s 6ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1179 - val_accuracy: 0.9890
# Epoch 31/60
# 1719/1719 [==============================] - 9s 6ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.1033 - val_accuracy: 0.9870
# Epoch 32/60
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.1044 - val_accuracy: 0.9892
# Epoch 33/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.0943 - val_accuracy: 0.9896
# Epoch 34/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 7.4026e-04 - accuracy: 0.9998 - val_loss: 0.1152 - val_accuracy: 0.9862
# Epoch 35/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.1276 - val_accuracy: 0.9878
# Epoch 36/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 0.1137 - val_accuracy: 0.9882
# Epoch 37/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.1134 - val_accuracy: 0.9898
# Epoch 38/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1094 - val_accuracy: 0.9860
# Epoch 39/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0996 - val_accuracy: 0.9906
# Epoch 40/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 5.3473e-04 - accuracy: 0.9998 - val_loss: 0.1173 - val_accuracy: 0.9888
# Epoch 41/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.1343 - val_accuracy: 0.9880
# Epoch 42/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.1644 - val_accuracy: 0.9872
# Epoch 43/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 0.1509 - val_accuracy: 0.9872
# Epoch 44/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 0.1132 - val_accuracy: 0.9898
# Epoch 45/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.1180 - val_accuracy: 0.9900
# Epoch 46/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.1601 - val_accuracy: 0.9874
# Epoch 47/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.1265 - val_accuracy: 0.9880
# Epoch 48/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1484 - val_accuracy: 0.9870
# Epoch 49/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1573 - val_accuracy: 0.9856
# Epoch 50/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.1498 - val_accuracy: 0.9860
# Epoch 51/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1710 - val_accuracy: 0.9852
# Epoch 52/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.1494 - val_accuracy: 0.9868
# Epoch 53/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.1499 - val_accuracy: 0.9874
# Epoch 54/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.1286 - val_accuracy: 0.9882
# Epoch 55/60
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.1706 - val_accuracy: 0.9868
# Epoch 56/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1675 - val_accuracy: 0.9868
# Epoch 57/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.1719 - val_accuracy: 0.9870
# Epoch 58/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 0.1791 - val_accuracy: 0.9892
# Epoch 59/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.1929 - val_accuracy: 0.9874
# Epoch 60/60
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.1831 - val_accuracy: 0.9880

# %%
plt.plot(history3.history['loss'])
plt.title('Model3 loss')
plt.ylabel('Train Loss')
plt.xlabel('Epoch')
plt.show()

plt.plot(history3.history['accuracy'], label = 'train acc')
plt.plot(history3.history['val_accuracy'], label = 'valid acc')
plt.title('Model3 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
#Plot the training loss of all models
plt.title('Model loss')
plt.ylabel('Train Loss')
plt.xlabel('Epoch')
plt.plot(history1.history['loss'], label = 'model1 loss' )
plt.plot(history2.history['loss'], label = 'model2 loss' )
plt.plot(history3.history['loss'], label = 'model3 loss' )
plt.legend(loc = 'best')
plt.savefig("CNN_MNIST_loss.png")

# %%
#Plot the accuracy of all models
plt.title('Model1 Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(history1.history['accuracy'], label = 'model1_train')
plt.plot(history1.history['val_accuracy'], label = 'model1_valid')
plt.plot(history2.history['accuracy'], label = 'model2_train')
plt.plot(history2.history['val_accuracy'], label = 'model2_valid')
plt.plot(history3.history['accuracy'], label = 'model3_train')
plt.plot(history3.history['val_accuracy'], label = 'model3_valid')
plt.legend()
plt.savefig("CNN_MNIST_acc.png")
